# %% [markdown]
# <a href="https://colab.research.google.com/github/jtk6301/python_6th_week/blob/main/mod2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
    return a+b
def sub(a,b):
    return a-b

print("mod2입니다.")
# Out:
# mod2입니다.

# %%
# !cat mod2.py
# Out:
# # -*- coding: utf-8 -*-
# """mod2.ipynb
#
# Automatically generated by Colaboratory.
#
# Original file is located at
#     https://colab.research.google.com/drive/1nPWKgeRiC6bjk0eO2il0OGTX-VcxkvHy
# """
#
# def add(a,b):
#     return a+b
# def sub(a,b):
#     return a-b
#
# print("mod2입니다.")
#
# !cat mod2.py
#
# import mod2
#
# print(mod2.add(1,2))
# print(mod2.sub(2,1))

# %%
import mod2

# %%
print(mod2.add(1,2))
print(mod2.sub(2,1))
# Out:
# 3
# 3
